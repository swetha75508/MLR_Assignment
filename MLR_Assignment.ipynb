# %% [markdown]
# ## Step 1: Exploratory Data Analysis (EDA) and Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('ToyotaCorolla - MLR.CSV')

# %%
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986    Diesel  90          0  2000      3          4
# 1  13750         23  72937    Diesel  90          0  2000      3          4
# 2  13950         24  41711    Diesel  90          0  2000      3          4
# 3  14950         26  48000    Diesel  90          0  2000      3          4
# 4  13750         30  38500    Diesel  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
df.tail()
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114

# %% [markdown]
# ## Summary statistics

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
d1={"Age_08_04":"age","cc":"cylinder_volume"}

# %%
df.rename(columns=d1,inplace=True)
df
# Out:
#       Price  age     KM Fuel_Type   HP  Automatic  cylinder_volume  Doors  \
# 0     13500   23  46986    Diesel   90          0             2000      3
# 1     13750   23  72937    Diesel   90          0             2000      3
# 2     13950   24  41711    Diesel   90          0             2000      3
# 3     14950   26  48000    Diesel   90          0             2000      3
# 4     13750   30  38500    Diesel   90          0             2000      3
# ...     ...  ...    ...       ...  ...        ...              ...    ...
# 1431   7500   69  20544    Petrol   86          0             1300      3
# 1432  10845   72  19000    Petrol   86          0             1300      3
# 1433   8500   71  17016    Petrol   86          0             1300      3
# 1434   7250   70  16916    Petrol   86          0             1300      3
# 1435   6950   76      1    Petrol  110          0             1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# ...

# %%
df.columns
# Out:
# Index(['Price', 'age', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cylinder_volume',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Price            1436 non-null   int64
#  1   age              1436 non-null   int64
#  2   KM               1436 non-null   int64
#  3   Fuel_Type        1436 non-null   object
#  4   HP               1436 non-null   int64
#  5   Automatic        1436 non-null   int64
#  6   cylinder_volume  1436 non-null   int64
#  7   Doors            1436 non-null   int64
#  8   Cylinders        1436 non-null   int64
#  9   Gears            1436 non-null   int64
#  10  Weight           1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
# check for missing value
df.isnull().sum()
# Out:
# Price              0
# age                0
# KM                 0
# Fuel_Type          0
# HP                 0
# Automatic          0
# cylinder_volume    0
# Doors              0
# Cylinders          0
# Gears              0
# Weight             0
# dtype: int64

# %% [markdown]
# ## Visualizations

# %%
# Histograms for continuous variables
df[['age', 'KM', 'HP', 'cylinder_volume', 'Weight', 'Price']].hist(bins=20, figsize=(12,8))
plt.show()

# %%
# Create a boxplot for the selected columns: HP, age, KM, and Weight
sns.boxplot(data=df[["HP", "age", "KM", "Weight"]])
plt.xlabel("Variables (HP, Age, KM, Weight)")
plt.ylabel("Values")
plt.show()

# %%
price=pd.DataFrame(df["Price"])
price
# Out:
#       Price
# 0     13500
# 1     13750
# 2     13950
# 3     14950
# 4     13750
# ...     ...
# 1431   7500
# 1432  10845
# 1433   8500
# 1434   7250
# 1435   6950
#
# [1436 rows x 1 columns]

# %%
age=pd.DataFrame(df["age"])
age
# Out:
#       age
# 0      23
# 1      23
# 2      24
# 3      26
# 4      30
# ...   ...
# 1431   69
# 1432   72
# 1433   71
# 1434   70
# 1435   76
#
# [1436 rows x 1 columns]

# %%
km=pd.DataFrame(df["KM"])
km
# Out:
#          KM
# 0     46986
# 1     72937
# 2     41711
# 3     48000
# 4     38500
# ...     ...
# 1431  20544
# 1432  19000
# 1433  17016
# 1434  16916
# 1435      1
#
# [1436 rows x 1 columns]

# %%
hp=pd.DataFrame(df["HP"])
hp
# Out:
#        HP
# 0      90
# 1      90
# 2      90
# 3      90
# 4      90
# ...   ...
# 1431   86
# 1432   86
# 1433   86
# 1434   86
# 1435  110
#
# [1436 rows x 1 columns]

# %%
auto=pd.DataFrame(df["Automatic"])
auto
# Out:
#       Automatic
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1431          0
# 1432          0
# 1433          0
# 1434          0
# 1435          0
#
# [1436 rows x 1 columns]

# %%
cyvolume=pd.DataFrame(df["cylinder_volume"])
cyvolume
# Out:
#       cylinder_volume
# 0                2000
# 1                2000
# 2                2000
# 3                2000
# 4                2000
# ...               ...
# 1431             1300
# 1432             1300
# 1433             1300
# 1434             1300
# 1435             1600
#
# [1436 rows x 1 columns]

# %%
doors=pd.DataFrame(df["Doors"])
doors
# Out:
#       Doors
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 1431      3
# 1432      3
# 1433      3
# 1434      3
# 1435      5
#
# [1436 rows x 1 columns]

# %%
cylinder=pd.DataFrame(df["Cylinders"])
cylinder
# Out:
#       Cylinders
# 0             4
# 1             4
# 2             4
# 3             4
# 4             4
# ...         ...
# 1431          4
# 1432          4
# 1433          4
# 1434          4
# 1435          4
#
# [1436 rows x 1 columns]

# %%
gear=pd.DataFrame(df["Gears"])
gear
# Out:
#       Gears
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# ...     ...
# 1431      5
# 1432      5
# 1433      5
# 1434      5
# 1435      5
#
# [1436 rows x 1 columns]

# %%
wt=pd.DataFrame(df["Weight"])
wt
# Out:
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 1 columns]

# %%
sns.pairplot(df,diag_kind='kde')
plt.show()
# Out:
# c:\Users\Aqsa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Aqsa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Aqsa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
correlation_matrix = df[["Price", "age", "KM", "HP", "Automatic", "cylinder_volume", "Doors", "Gears", "Weight"]].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Between Variables")
plt.show()

# %% [markdown]
# ##With the observations we can say that:
# Price and age have a strong negative relationship – as cars get older, their price drops a lot.
#
# Price and kilometers (KM) have a medium negative relationship – cars with more kilometers tend to have lower prices.
#
# Price and weight show a medium positive relationship – heavier cars generally have higher prices.
#
# Price and horsepower (HP) have a weak positive relationship – cars with more horsepower tend to have slightly higher prices.
#
# Age and weight show a weak negative relationship – older cars are usually a bit lighter.
#
# The other variables don't seem to have a clear impact on price.

# %%
# Barplot for categorical variable 'FuelType'
sns.countplot(x='Fuel_Type', data=df)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## a. Handling Missing Values:
# If any columns have missing data, decide whether to fill them or drop those rows/columns.

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
# Out:
# C:\Users\Aqsa\AppData\Local\Temp\ipykernel_15408\1503503937.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)

# %% [markdown]
# ## b. Categorical Encoding:
# Convert categorical features such as FuelType into numeric values using one-hot encoding.

# %%
# One-hot encoding for 'FuelType'
df = pd.get_dummies(df, columns=['Fuel_Type'], drop_first=True)

# %%
df
# Out:
#       Price  age     KM   HP  Automatic  cylinder_volume  Doors  Cylinders  \
# 0     13500   23  46986   90          0             2000      3          4
# 1     13750   23  72937   90          0             2000      3          4
# 2     13950   24  41711   90          0             2000      3          4
# 3     14950   26  48000   90          0             2000      3          4
# 4     13750   30  38500   90          0             2000      3          4
# ...     ...  ...    ...  ...        ...              ...    ...        ...
# 1431   7500   69  20544   86          0             1300      3          4
# 1432  10845   72  19000   86          0             1300      3          4
# 1433   8500   71  17016   86          0             1300      3          4
# 1434   7250   70  16916   86          0             1300      3          4
# 1435   6950   76      1  110          0             1600      5          4
#
#       Gears  Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %% [markdown]
# ## c. Scaling Features:
# Scale continuous variables to standardize them, especially for Lasso and Ridge.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['age', 'KM', 'HP', 'cylinder_volume', 'Weight']] = scaler.fit_transform(df[['age', 'KM', 'HP', 'cylinder_volume', 'Weight']])

# %%
df
# Out:
#       Price       age        KM        HP  Automatic  cylinder_volume  Doors  \
# 0     13500 -1.771966 -0.574695 -0.768042          0         0.997419      3
# 1     13750 -1.771966  0.117454 -0.768042          0         0.997419      3
# 2     13950 -1.718184 -0.715386 -0.768042          0         0.997419      3
# 3     14950 -1.610620 -0.547650 -0.768042          0         0.997419      3
# 4     13750 -1.395491 -0.801028 -0.768042          0         0.997419      3
# ...     ...       ...       ...       ...        ...              ...    ...
# 1431   7500  0.702015 -1.279939 -1.035138          0        -0.652594      3
# 1432  10845  0.863362 -1.321120 -1.035138          0        -0.652594      3
# 1433   8500  0.809579 -1.374036 -1.035138          0        -0.652594      3
# 1434   7250  0.755797 -1.376703 -1.035138          0        -0.652594      3
# 1435   6950  1.078490 -1.827849  0.567440          0         0.054555      5
#
# ...

# %% [markdown]
# ## Step 2: Splitting the Dataset
# Now that your data is preprocessed, split it into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

# Define features (X) and target (y)
X = df.drop(['Price'], axis=1)
y = df['Price']

# Split data into 80% training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
X_train
# Out:
#            age        KM        HP  Automatic  cylinder_volume  Doors  \
# 877   0.110411 -0.173611  0.567440          0         0.054555      5
# 255  -0.750104 -0.404958  0.567440          0         0.054555      5
# 884   0.110411 -0.191774  0.567440          0         0.054555      5
# 106  -2.256006 -1.521155  0.567440          0         0.054555      3
# 325  -0.803887 -0.921049  0.567440          0         0.054555      5
# ...        ...       ...       ...        ...              ...    ...
# 924   0.379322 -0.307608 -1.035138          0        -0.652594      5
# 1247  0.702015  0.279162 -1.035138          0        -0.652594      3
# 271  -0.965233 -0.542396  0.567440          0         0.054555      5
# 474  -0.427411 -0.115761  0.567440          0         0.054555      3
# 1379  0.970926 -0.330759  0.567440          0         0.054555      4
#
#       Cylinders  Gears    Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
y_train
# Out:
# 877      9950
# 255     12900
# 884      9950
# 106     18800
# 325     11950
#         ...
# 924      9950
# 1247     6900
# 271     12950
# 474     10450
# 1379     7750
# Name: Price, Length: 1148, dtype: int64

# %%
X_test
# Out:
#            age        KM        HP  Automatic  cylinder_volume  Doors  \
# 83   -1.341709 -1.394786  0.567440          1         0.054555      5
# 1129  0.809579  1.039723  0.567440          0         0.054555      3
# 1368  0.755797 -0.285497  0.567440          0         0.054555      3
# 522  -0.158500 -0.495134  0.567440          0         0.054555      5
# 318  -0.750104 -0.841035 -0.300623          0        -0.416878      3
# ...        ...       ...       ...        ...              ...    ...
# 244  -1.234144 -0.300433  0.567440          0         0.054555      5
# 280  -1.126580 -0.592885 -0.300623          0        -0.416878      5
# 1398  1.024708 -0.536982  0.567440          0         0.054555      5
# 251  -0.696322 -0.371619  0.567440          0         0.054555      4
# 864   0.648233 -0.120908  0.567440          0         0.054555      5
#
#       Cylinders  Gears    Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
y_test
# Out:
# 83      17950
# 1129     7750
# 1368     9750
# 522      9650
# 318      9900
#         ...
# 244     11690
# 280     12950
# 1398     8950
# 251     10850
# 864      8950
# Name: Price, Length: 288, dtype: int64

# %% [markdown]
# ## Step 3:  Building Multiple Linear Regression Models
# You’ll now build multiple linear regression models using sklearn. We will build 3 different models by varying the input features.

# %% [markdown]
#  ## Model 1: Using All Features

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Initialize and train the model
model1 = LinearRegression()
model1.fit(X_train, y_train)

# Predict on test set
y_pred1 = model1.predict(X_test)

# Model evaluation
print("R-squared:", r2_score(y_test, y_pred1))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred1)))
# Out:
# R-squared: 0.83233863489449
# RMSE: 1507.220086622895

# %% [markdown]
#  ## Model 2: Removing Correlated Features
# From the correlation heatmap, remove one or two highly correlated features. For example, if CC and HP are highly correlated, remove one.

# %%
X_train2 = X_train.drop(['cylinder_volume'], axis=1)
X_test2 = X_test.drop(['cylinder_volume'], axis=1)

# Train model
model2 = LinearRegression()
model2.fit(X_train2, y_train)

# Predict and evaluate
y_pred2 = model2.predict(X_test2)
print("R-squared:", r2_score(y_test, y_pred2))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred2)))
# Out:
# R-squared: 0.832271163831373
# RMSE: 1507.5233273622664

# %% [markdown]
# ## Model 3: Using Only Important Features
# From EDA, use only the features that have a strong correlation with Price (e.g., Age, KM, HP).

# %%
# Select only important features
X_train3 = X_train[['age', 'KM', 'HP']]
X_test3 = X_test[['age', 'KM', 'HP']]

# Train model
model3 = LinearRegression()
model3.fit(X_train3, y_train)

# Predict and evaluate
y_pred3 = model3.predict(X_test3)
print("R-squared:", r2_score(y_test, y_pred3))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred3)))
# Out:
# R-squared: 0.8063929629609583
# RMSE: 1619.6483900105413

# %% [markdown]
# ## Step 4: Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Assuming you have a trained model called 'model'
y_pred = model1.predict(X_test)
# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print out the evaluation metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Absolute Error (MAE): 989.99003768417
# Mean Squared Error (MSE): 2271712.389519527

# %% [markdown]
# ## Step 5: Lasso and Ridge Regression
# Now, apply Lasso and Ridge regression, which add regularization to prevent overfitting.
#
# ## Lasso Regression
# Lasso shrinks the coefficients of less important variables to zero, effectively performing feature selection.

# %%
from sklearn.linear_model import Lasso

# Train Lasso regression model
lasso = Lasso(alpha=0.1)  # Alpha is the regularization strength
lasso.fit(X_train, y_train)

# Predict and evaluate
y_pred_lasso = lasso.predict(X_test)
print("Lasso R-squared:", r2_score(y_test, y_pred_lasso))
print("Lasso RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_lasso)))
# Out:
# Lasso R-squared: 0.8323887596012602
# Lasso RMSE: 1506.994767533189

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

# Train Ridge regression model
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

# Predict and evaluate
y_pred_ridge = ridge.predict(X_test)
print("Ridge R-squared:", r2_score(y_test, y_pred_ridge))
print("Ridge RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_ridge)))
# Out:
# Ridge R-squared: 0.8326447752398789
# Ridge RMSE: 1505.8434077966385

# %% [markdown]
# ## INTERVIEW QUESTION:
# ## 1.What is Normalization & Standardization and how is it helpful?
# Normalization /Standardization is used to transform our numerical data within a range of 0 to 1.this is done to avoid the bad effect on our predictions due to having different units in our population data,
# And standardizing the data also reduces the computation time if we have a big dataset.We can use StandardScaler to standardize our data.

# %% [markdown]
# ## 2.What techniques can be used to address multicollinearity in multiple linear regression.
# To address multicollinearity in multiple linear regression, we can use the following techniques:
#
# Remove highly correlated predictors: Identify and eliminate variables that are strongly correlated with each other.
#
# Principal Component Analysis (PCA): Reduce the dimensionality of the data by transforming variables into uncorrelated components.
#
# Ridge Regression (L2 regularization): Adds a penalty to the size of the coefficients, reducing multicollinearity impact.
#
# Lasso Regression (L1 regularization): Shrinks some coefficients to zero, effectively performing feature selection.
#
# Variance Inflation Factor (VIF): Identify and remove variables with high VIF values to reduce multicollinearity.
